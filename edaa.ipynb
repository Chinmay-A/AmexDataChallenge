# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('training_set.csv')
df.head()
# Out:
#    match id     team1  team1_id  \
# 0   9331181        Ba     11283
# 1   8797060        Ed        20
# 2   9433269        We     10576
# 3   9587073  Ga An Ws     36084
# 4   9516457     Pb Ks     30407
#
#                                     team1_roster_ids  team2  team2_id  \
# 0  9373356.0:7857520.0:4232164.0:4566540.0:329940...  Hl Ph     12634
# 1  2089079.0:6139370.0:2076192.0:62432.0:2083409....  Wt Is        41
# 2  3298427.0:2288789.0:7773338.0:3519011.0:368195...     Ne      8987
# 3  8127230.0:4690328.0:4069666.0:7960847.0:469018...  Bs Rs     36070
# 4  8127181.0:197658.0:4239038.0:2398346.0:5053082...  Gt Ts     48341
#
#                                     team2_roster_ids    winner  winner_id  \
# 0  3500958.0:4231751.0:2735081.0:2035102.0:369833...     Hl Ph      12634
# 1  4690258.0:4069666.0:4230127.0:1942317.0:161392...        Ed         20
# 2  4003390.0:1749075.0:1626526.0:4172447.0:551672...        We      10576
# ...

# %%
df.columns
# Out:
# Index(['match id', 'team1', 'team1_id', 'team1_roster_ids', 'team2',
#        'team2_id', 'team2_roster_ids', 'winner', 'winner_id', 'toss winner',
#        'toss decision', 'venue', 'city', 'match_dt', 'lighting', 'series_name',
#        'season', 'ground_id', 'team_count_50runs_last15', 'team_winp_last5',
#        'team1only_avg_runs_last15', 'team1_winp_team2_last15',
#        'ground_avg_runs_last15', 'momentum_score', 'location_score',
#        'batting_score', 'bowling_score'],
#       dtype='object')

# %%
df['winner']=(df['winner_id']==df['team1_id'])

# %%
winnersarr=[]

for i in range(len(df)):

    if(df['winner'][i]):
        winnersarr.append(1)
    else:
        winnersarr.append(0)

df['winners']=winnersarr

# %%
df.head()
# Out:
#    match id     team1  team1_id  \
# 0   9331181        Ba     11283
# 1   8797060        Ed        20
# 2   9433269        We     10576
# 3   9587073  Ga An Ws     36084
# 4   9516457     Pb Ks     30407
#
#                                     team1_roster_ids  team2  team2_id  \
# 0  9373356.0:7857520.0:4232164.0:4566540.0:329940...  Hl Ph     12634
# 1  2089079.0:6139370.0:2076192.0:62432.0:2083409....  Wt Is        41
# 2  3298427.0:2288789.0:7773338.0:3519011.0:368195...     Ne      8987
# 3  8127230.0:4690328.0:4069666.0:7960847.0:469018...  Bs Rs     36070
# 4  8127181.0:197658.0:4239038.0:2398346.0:5053082...  Gt Ts     48341
#
#                                     team2_roster_ids  winner  winner_id  \
# 0  3500958.0:4231751.0:2735081.0:2035102.0:369833...   False      12634
# 1  4690258.0:4069666.0:4230127.0:1942317.0:161392...    True         20
# 2  4003390.0:1749075.0:1626526.0:4172447.0:551672...    True      10576
# ...

# %%
toss_code=[]

for i in range(len(df)):
    if(df['toss winner'][i]!=df['team1'][i] and df['toss winner'][i]!=df['team2'][i]):
        print("Issue Detected in row: ")
        print(i)
    if(df['toss winner'][i]==df['team1'][i] and df['toss decision'][i]=="bat"):
       print("OK")
       toss_code.append(1)
    elif(df['toss winner'][i]==df['team2'][i] and df['toss decision'][i]=="field"):
        print("OKA")
        toss_code.append(1)
    else:
        print("BHA")
        toss_code.append(0)

df['tossA']=toss_code
# Out:
# OKA
# OKA
# OKA
# OK
# OKA
# OKA
# OKA
# OK
# OKA
# OKA
# OKA
# OK
# OKA
# OK
# OKA
# OK
# OKA
# OKA
# OKA
# OK
# OK
# OK
# OK
# OK
# OK
# OKA
# OKA
# OK
# OKA
# OKA
# OKA
# OKA
# OK
# OK
# OK
# OKA
# OKA
# OKA
# OKA
# OKA
# OKA
# OKA
# OK
# OK
# OKA
# OK
# OK
# OKA
# OKA
# OKA
# OK
# OKA
# OK
# OKA
# OKA
# OK
# OKA
# OKA
# OKA
# OKA
# OK
# OKA
# OK
# OK
# OKA
# OKA
# OKA
# OK
# OK
# OKA
# OKA
# OKA
# OKA
# OK
# OKA
# OKA
# OK
# OKA
# OK
# OKA
# OKA
# OKA
# OK
# OKA
# OKA
# OKA
# OKA
# OKA
# OK
# OK
# OKA
# OK
# OKA
# OKA
# OKA
# OKA
# OKA
# OKA
# OKA
# OKA
# OK
# OK
# OKA
# OKA
# OK
# OK
# OK
# OKA
# OKA
# OKA
# OKA
# OKA
# OKA
# OK
# OK
# OKA
# OK
# OKA
# OKA
# OKA
# OKA
# OKA
# OKA
# OKA
# OKA
# OKA
# OK
# OKA
# OKA
# OK
# OKA
# OK
# OKA
# OK
# OK
# OKA
# OKA
# OK
# OKA
# OK
# OKA
# OKA
# OKA
# OK
# OKA
# OKA
# OKA
# OKA
# OKA
# OKA
# OK
# OKA
# OKA
# OKA
# OK
# OKA
# OKA
# OKA
# OK
# OKA
# OKA
# OKA
# OK
# OK
# OKA
# OK
# OKA
# OKA
# OKA
# OK
# OKA
# OKA
# OK
# OK
# OKA
# OK
# ...

# %%
df.head()
# Out:
#    match id     team1  team1_id  \
# 0   9331181        Ba     11283
# 1   8797060        Ed        20
# 2   9433269        We     10576
# 3   9587073  Ga An Ws     36084
# 4   9516457     Pb Ks     30407
#
#                                     team1_roster_ids  team2  team2_id  \
# 0  9373356.0:7857520.0:4232164.0:4566540.0:329940...  Hl Ph     12634
# 1  2089079.0:6139370.0:2076192.0:62432.0:2083409....  Wt Is        41
# 2  3298427.0:2288789.0:7773338.0:3519011.0:368195...     Ne      8987
# 3  8127230.0:4690328.0:4069666.0:7960847.0:469018...  Bs Rs     36070
# 4  8127181.0:197658.0:4239038.0:2398346.0:5053082...  Gt Ts     48341
#
#                                     team2_roster_ids  winner  winner_id  \
# 0  3500958.0:4231751.0:2735081.0:2035102.0:369833...   False      12634
# 1  4690258.0:4069666.0:4230127.0:1942317.0:161392...    True         20
# 2  4003390.0:1749075.0:1626526.0:4172447.0:551672...    True      10576
# ...

# %%
relevant_columns=['match id','team1_id','team2_id','team_count_50runs_last15','team_winp_last5','team1only_avg_runs_last15','team1_winp_team2_last15','ground_avg_runs_last15','momentum_score','location_score','batting_score','bowling_score','winners']

# %%
df_new=df[relevant_columns]
df_new.to_csv('train_ready.csv',index=False)
