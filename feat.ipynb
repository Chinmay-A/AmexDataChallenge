# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('./new_dataset.csv')
df.head()
# Out:
#    bat_above_50_a  bat_above_50_b  bat_above_75_a  bat_above_75_b  \
# 0        0.379331        0.176923        0.069295        0.000000
# 1        0.720803        0.471635        0.190112        0.110651
# 2        0.957247        1.228401        0.075000        0.235656
# 3        0.604978        0.703178        0.108259        0.355808
# 4        0.675176        0.704371        0.229814        0.132605
#
#    wickets_in_inning_a  wickets_in_inning_b  runs_in_inning_a  \
# 0             6.625000             7.500000        151.875000
# 1             6.333333             6.500000        162.666667
# 2             6.000000             7.153846        164.000000
# 3             7.272727             6.250000        162.909091
# 4             5.222222             6.666667        162.555556
#
#    runs_in_inning_b  direct_encounter  winner
# 0        125.500000               1.0       0
# 1        146.785714               0.5       1
# 2        138.538462               0.0       1
# 3        152.583333               0.5       1
# 4        161.666667               0.5       0

# %%
df.columns
# Out:
# Index(['bat_above_50_a', 'bat_above_50_b', 'bat_above_75_a', 'bat_above_75_b',
#        'wickets_in_inning_a', 'wickets_in_inning_b', 'runs_in_inning_a',
#        'runs_in_inning_b', 'direct_encounter', 'winner'],
#       dtype='object')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
important_feat=['Aavg_boundaries','Aavg_runs','Bavg_boundaries','Bavg_runs','Adots_frac','Bdots_frac']
